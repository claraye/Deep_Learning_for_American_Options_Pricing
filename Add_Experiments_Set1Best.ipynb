# %%
# Require: tensorflow-1.13
# !pip install tensorflow==1.13.1
# Require: pandas-0.25+
# !pip install pandas --upgrade
# if upgraded, please restart the kernel to let it take effect
# Out:
# Requirement already satisfied: tensorflow==1.13.1 in d:\anaconda_\lib\site-packages (1.13.1)
# Requirement already satisfied: astor>=0.6.0 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (1.23.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (3.9.2)
# Requirement already satisfied: absl-py>=0.1.6 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: gast>=0.2.0 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (0.3.2)
# Requirement already satisfied: numpy>=1.13.3 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (1.16.5)
# Requirement already satisfied: six>=1.10.0 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (1.12.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (1.13.0)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (1.13.1)
# Requirement already satisfied: wheel>=0.26 in d:\anaconda_\lib\site-packages (from tensorflow==1.13.1) (0.33.6)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorflow==1.13.1) (1.0.8)
# Requirement already satisfied: setuptools in d:\anaconda_\lib\site-packages (from protobuf>=3.6.1->tensorflow==1.13.1) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kaiqi wu\appdata\roaming\python\python37\site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\anaconda_\lib\site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (0.16.0)
# Requirement already satisfied: h5py in d:\anaconda_\lib\site-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (2.9.0)
# Requirement already up-to-date: pandas in d:\anaconda_\lib\site-packages (0.25.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in d:\anaconda_\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in d:\anaconda_\lib\site-packages (from pandas) (1.16.5)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in d:\anaconda_\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in d:\anaconda_\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
import sys
sys.path.append('data_generation')
sys.path.append('util')
sys.path.append('neural_networks')
sys.path.append('experiments')

# %%
import tensorflow as tf
from dataset_manager import DataSetManager
from dataset import DataSetKey
from my_enums import Pricers,Generators
from ds_spec import DsSpecs
from experiment_manager import ExperimentManager
from my_config import Config
import os
# Out:
# Not Running In Google Datalab
# Not Running in Google Datalab

# %%
best_archs = [
    ((5,tf.nn.relu,0.25),),
    ((10,tf.nn.relu,0.25),),
    ((20,tf.nn.relu,0.25),),
    ((5,tf.nn.elu,0.25),(5,tf.nn.relu,0.25)),
    ((10,tf.nn.elu,0.25),(10,tf.nn.relu,0.25)),
    ((20,tf.nn.relu,0.25),(20,tf.nn.leaky_relu,0.25))
]

# %%
dsm = DataSetManager.get_default_in_mem_DSM()
em = ExperimentManager.create_or_load(os.path.join(Config.experiments_dir,'set1bests'),dsm)
training_sizes = [500000]#[25000,50000,100000,200000]
archs = best_archs
dskey = DataSetKey(Generators.Halton,Pricers.JuZhongWhaley,Pricers.BSFormula,DsSpecs.SPEC_3_3_1)
learn_rate = 0.1
# Out:
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_0
# Loading DataSetKey(Generators.Uniform, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_1
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_2
# Loading DataSetKey(Generators.Halton, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_3
# Loading DataSetKey(Generators.Halton, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_4
# Loading DataSetKey(Generators.Halton, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_1_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_5
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_6
# Loading DataSetKey(Generators.Uniform, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_7
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_8
# Loading DataSetKey(Generators.Halton, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_9
# Loading DataSetKey(Generators.Halton, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_10
# Loading DataSetKey(Generators.Halton, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_2_1_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_11
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_12
# Loading DataSetKey(Generators.Uniform, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_13
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_14
# Loading DataSetKey(Generators.Halton, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_15
# Loading DataSetKey(Generators.Halton, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_16
# Loading DataSetKey(Generators.Halton, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_1_2_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_17
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_18
# Loading DataSetKey(Generators.Uniform, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_19
# Loading DataSetKey(Generators.Uniform, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_20
# Loading DataSetKey(Generators.Halton, Pricers.JuZhong, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_21
# Loading DataSetKey(Generators.Halton, Pricers.Whaley, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_22
# Loading DataSetKey(Generators.Halton, Pricers.JuZhongWhaley, Pricers.BSFormula, DsSpecs.SPEC_3_3_1) at C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Data\datasets\ds_23

# %%
#run all architectures
for train_size in training_sizes:
    for arch in archs:
        model_key = (arch,learn_rate)
        em.new_exp(dskey,model_key,train_size)

# %%
df = em.get_info_df()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_0\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_1\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_2\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_3\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_4\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_5\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_6\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_7\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_8\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_9\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_10\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_11\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_12\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_13\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_14\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_15\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_16\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_17\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_18\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_19\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_20\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_21\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_22\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_23\model\model-50
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_24\model\model-0
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_25\model\model-0
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_26\model\model-0
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_27\model\model-0
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_28\model\model-0
# INFO:tensorflow:Restoring parameters from C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\Experiments\set1bests\exp_29\model\model-0

# %%
df
# Out:
#             Generator        American Pricer    European Pricer  \
# 0   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 1   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 2   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 3   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 4   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 5   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 6   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 7   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 8   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 9   Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 10  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 11  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 12  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 13  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 14  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 15  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 16  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 17  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 18  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 19  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 20  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 21  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 22  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 23  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 24  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 25  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 26  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 27  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 28  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
# 29  Generators.Halton  Pricers.JuZhongWhaley  Pricers.BSFormula
#
#                  Specs     nodes    Activation Funcs    drop rates  \
# 0   DsSpecs.SPEC_3_3_1       [5]              [relu]        [0.25]
# 1   DsSpecs.SPEC_3_3_1      [10]              [relu]        [0.25]
# 2   DsSpecs.SPEC_3_3_1      [20]              [relu]        [0.25]
# 3   DsSpecs.SPEC_3_3_1    [5, 5]         [elu, relu]  [0.25, 0.25]
# 4   DsSpecs.SPEC_3_3_1  [10, 10]         [elu, relu]  [0.25, 0.25]
# 5   DsSpecs.SPEC_3_3_1  [20, 20]  [relu, leaky_relu]  [0.25, 0.25]
# 6   DsSpecs.SPEC_3_3_1       [5]              [relu]        [0.25]
# 7   DsSpecs.SPEC_3_3_1      [10]              [relu]        [0.25]
# 8   DsSpecs.SPEC_3_3_1      [20]              [relu]        [0.25]
# 9   DsSpecs.SPEC_3_3_1    [5, 5]         [elu, relu]  [0.25, 0.25]
# 10  DsSpecs.SPEC_3_3_1  [10, 10]         [elu, relu]  [0.25, 0.25]
# 11  DsSpecs.SPEC_3_3_1  [20, 20]  [relu, leaky_relu]  [0.25, 0.25]
# 12  DsSpecs.SPEC_3_3_1       [5]              [relu]        [0.25]
# 13  DsSpecs.SPEC_3_3_1      [10]              [relu]        [0.25]
# 14  DsSpecs.SPEC_3_3_1      [20]              [relu]        [0.25]
# 15  DsSpecs.SPEC_3_3_1    [5, 5]         [elu, relu]  [0.25, 0.25]
# 16  DsSpecs.SPEC_3_3_1  [10, 10]         [elu, relu]  [0.25, 0.25]
# 17  DsSpecs.SPEC_3_3_1  [20, 20]  [relu, leaky_relu]  [0.25, 0.25]
# 18  DsSpecs.SPEC_3_3_1       [5]              [relu]        [0.25]
# 19  DsSpecs.SPEC_3_3_1      [10]              [relu]        [0.25]
# 20  DsSpecs.SPEC_3_3_1      [20]              [relu]        [0.25]
# 21  DsSpecs.SPEC_3_3_1    [5, 5]         [elu, relu]  [0.25, 0.25]
# 22  DsSpecs.SPEC_3_3_1  [10, 10]         [elu, relu]  [0.25, 0.25]
# 23  DsSpecs.SPEC_3_3_1  [20, 20]  [relu, leaky_relu]  [0.25, 0.25]
# 24  DsSpecs.SPEC_3_3_1       [5]              [relu]        [0.25]
# 25  DsSpecs.SPEC_3_3_1      [10]              [relu]        [0.25]
# 26  DsSpecs.SPEC_3_3_1      [20]              [relu]        [0.25]
# 27  DsSpecs.SPEC_3_3_1    [5, 5]         [elu, relu]  [0.25, 0.25]
# 28  DsSpecs.SPEC_3_3_1  [10, 10]         [elu, relu]  [0.25, 0.25]
# 29  DsSpecs.SPEC_3_3_1  [20, 20]  [relu, leaky_relu]  [0.25, 0.25]
#
#     epochs run  train_size                                            exp_dir
# 0           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 1           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 2           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 3           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 4           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 5           50       25000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 6           50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 7           50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 8           50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 9           50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 10          50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 11          50       50000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 12          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 13          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 14          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 15          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 16          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 17          50      100000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 18          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 19          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 20          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 21          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 22          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 23          50      200000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 24           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 25           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 26           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 27           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 28           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
# 29           0      500000  C:\Users\Kaiqi Wu\Desktop\1229\Final_Project\E...
