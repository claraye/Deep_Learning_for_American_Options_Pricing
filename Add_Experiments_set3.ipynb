# %% [markdown]
# ### Add experiments on the dataset 3:
#   - Halton qmc sequence;
#   - Ju-Zhong/Whaley approximation;
#   - Fixing K = 1, but NOT including EU_Price in inputs

# %%
# Require: tensorflow-1.13
# !pip install tensorflow=='1.13.1'
# Require: pandas-0.25+
# !pip install pandas --upgrade
# if upgraded, please restart the kernel to let it take effect
# Out:
# Requirement already satisfied: tensorflow==1.13.1 in /usr/local/envs/py3env/lib/python3.5/site-packages (1.13.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.13.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (3.6.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.10.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (0.7.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (0.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.0.8)
# Requirement already satisfied: wheel>=0.26 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (0.31.1)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.13.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.21.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow==1.13.1) (1.14.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (2.6.11)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (0.15.4)
# Requirement already satisfied: setuptools in /usr/local/envs/py3env/lib/python3.5/site-packages (from protobuf>=3.6.1->tensorflow==1.13.1) (40.2.0)
# Requirement already satisfied: h5py in /usr/local/envs/py3env/lib/python3.5/site-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (2.7.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1) (2.0.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/envs/py3env/lib/python3.5/site-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1) (5.1.3)
# Requirement already up-to-date: pandas in /usr/local/envs/py3env/lib/python3.5/site-packages (0.25.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/envs/py3env/lib/python3.5/site-packages (from pandas) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/envs/py3env/lib/python3.5/site-packages (from pandas) (1.14.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/envs/py3env/lib/python3.5/site-packages (from pandas) (2018.4)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/envs/py3env/lib/python3.5/site-packages (from python-dateutil>=2.6.1->pandas) (1.10.0)

# %%
import sys
sys.path.append('data_generation')
sys.path.append('util')
sys.path.append('neural_networks')
sys.path.append('experiments')

# %%
import tensorflow as tf
from dataset_manager import DataSetManager
from dataset import DataSetKey
from my_enums import Pricers,Generators
from ds_spec import DsSpecs
from experiment_manager import ExperimentManager
from my_config import Config
import os
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def get_all_architectures():
    nodes = [5,10,20]
    afs = [tf.nn.relu,tf.nn.leaky_relu,tf.nn.elu,tf.nn.sigmoid,tf.nn.tanh]
    one_layer_nodes = [(n,) for n in nodes]
    two_layer_nodes = [(n,n) for n in nodes]
    one_layer_afs = [ (af,) for af in afs]
    two_layer_afs = [ (af1,af2) for af1 in afs for af2 in afs]
    one_layer_archs = [tuple(zip(n,af,(0.0,))) for n in one_layer_nodes for af in one_layer_afs]
    two_layer_archs = [tuple(zip(n,af,(0.0,0.0))) for n in two_layer_nodes for af in two_layer_afs]
    return one_layer_archs + two_layer_archs

# %%
dsm = DataSetManager.get_set3_in_mem_DSM()

# %%
em = ExperimentManager.create_or_load(os.path.join(Config.experiments_dir,'set3'),dsm)

# %% [markdown]
# ### Set 3: Add Experiments <br>
#  - Using Dataset with:
#    - HaltonGenerator, JuZhongWhaleyPricer, and SPEC_1_2_1(fixing k=1, but not using European Price as part of input)<br>
#  - run: all combinations of nodes and activation functions (drop_rate = 0.0) <br>
#    - for each architecture, run with training sizes [2000,5000,10000,15000,20000,25000] for 50 epochs <br>
# (NOTE: here only add experiments, will run them in Run_Experiments_set3.ipynb)

# %%
#training_sizes = [2000,5000,10000,15000,20000,25000]
training_sizes = [25000]
archs = get_all_architectures()
#archs = [((10,tf.nn.relu,0.0),(10,tf.nn.relu,0.0))]
dskey = DataSetKey(Generators.Halton,Pricers.JuZhongWhaley,Pricers.BSFormula,DsSpecs.SPEC_1_2_1)
learn_rate = 0.1

# %%
dsm.get_ds(dskey).get_info_df()['location']
# Out:
# 0    /content/datalab/Data/datasets/ds_17
# Name: location, dtype: object

# %%
#run all architectures
for train_size in training_sizes:
    for arch in archs:
        model_key = (arch,learn_rate)
        em.new_exp(dskey,model_key,train_size)
# Out:
# WARNING:tensorflow:From /usr/local/envs/py3env/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/envs/py3env/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
experiments_info_df = em.get_info_df()
# Out:
# WARNING:tensorflow:From /usr/local/envs/py3env/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_78/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_32/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_22/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_73/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_5/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_75/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_35/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_52/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_74/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_16/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_51/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_10/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_23/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_27/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_47/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_54/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_72/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_48/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_67/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_31/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_85/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_45/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_88/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_84/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_79/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_41/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_82/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_68/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_65/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_38/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_60/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_69/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_25/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_33/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_53/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_15/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_13/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_28/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_40/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_37/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_62/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_81/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_89/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_43/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_42/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_26/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_76/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_77/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_58/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_30/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_3/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_57/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_24/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_56/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_87/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_20/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_0/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_12/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_21/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_18/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_46/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_9/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_6/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_29/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_50/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_61/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_80/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_83/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_86/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_7/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_70/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_8/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_71/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_4/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_1/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_17/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_63/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_2/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_59/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_64/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_49/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_55/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_34/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_44/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_19/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_14/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_36/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_39/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_11/model/model-0
# INFO:tensorflow:Restoring parameters from /content/datalab/Experiments/set3/exp_66/model/model-0

# %%
experiments_info_df
# Out:
#           American Pricer    European Pricer          Generator  \
# 0   Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 1   Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 2   Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 3   Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 4   Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# ..                    ...                ...                ...
# 85  Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 86  Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 87  Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 88  Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
# 89  Pricers.JuZhongWhaley  Pricers.BSFormula  Generators.Halton
#
#                  Specs       Activation Funcs  drop rates  epochs run  \
# 0   DsSpecs.SPEC_1_2_1         [elu, sigmoid]  [0.0, 0.0]           0
# 1   DsSpecs.SPEC_1_2_1         [sigmoid, elu]  [0.0, 0.0]           0
# 2   DsSpecs.SPEC_1_2_1      [leaky_relu, elu]  [0.0, 0.0]           0
# 3   DsSpecs.SPEC_1_2_1  [leaky_relu, sigmoid]  [0.0, 0.0]           0
# 4   DsSpecs.SPEC_1_2_1                 [relu]       [0.0]           0
# ..                 ...                    ...         ...         ...
# 85  DsSpecs.SPEC_1_2_1                 [tanh]       [0.0]           0
# 86  DsSpecs.SPEC_1_2_1     [tanh, leaky_relu]  [0.0, 0.0]           0
# 87  DsSpecs.SPEC_1_2_1           [tanh, tanh]  [0.0, 0.0]           0
# 88  DsSpecs.SPEC_1_2_1           [leaky_relu]       [0.0]           0
# 89  DsSpecs.SPEC_1_2_1     [relu, leaky_relu]  [0.0, 0.0]           0
#
#        nodes  train_size                                   exp_dir
# 0   [20, 20]       25000  /content/datalab/Experiments/set3/exp_78
# 1     [5, 5]       25000  /content/datalab/Experiments/set3/exp_32
# 2     [5, 5]       25000  /content/datalab/Experiments/set3/exp_22
# 3   [20, 20]       25000  /content/datalab/Experiments/set3/exp_73
# 4       [10]       25000   /content/datalab/Experiments/set3/exp_5
# ..       ...         ...                                       ...
# 85      [20]       25000  /content/datalab/Experiments/set3/exp_14
# 86    [5, 5]       25000  /content/datalab/Experiments/set3/exp_36
# 87    [5, 5]       25000  /content/datalab/Experiments/set3/exp_39
# 88      [20]       25000  /content/datalab/Experiments/set3/exp_11
# 89  [20, 20]       25000  /content/datalab/Experiments/set3/exp_66
#
# [90 rows x 10 columns]
